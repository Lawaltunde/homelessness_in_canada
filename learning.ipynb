# %%
import pandas as pd

# %%
path_canada = r"C:\Users\hp\Desktop\Cambrian course outline\Business Analytics Courses\QMM7300\canada_homelessness_data.csv"
path_ontario = r"C:\Users\hp\Desktop\Cambrian course outline\Business Analytics Courses\QMM7300\canada_homelessness_data.csv"
path_sudbury = r"C:\Users\hp\Desktop\Cambrian course outline\Business Analytics Courses\QMM7300\canada_homelessness_data.csv"

# %%
df_canada = pd.read_csv(path_canada)
df_ontario = pd.read_csv(path_ontario)
df_sudbury = pd.read_csv(path_sudbury)
df_canada
# Out:
#      YEAR     GEO            Type of shelter         Target population  \
# 0    2016  Canada          Emergency shelter  Total, target population
# 1    2016  Canada          Emergency shelter     General - all genders
# 2    2016  Canada          Emergency shelter             General - men
# 3    2016  Canada          Emergency shelter           General - women
# 4    2016  Canada          Emergency shelter                     Youth
# 5    2016  Canada          Emergency shelter                    Family
# 6    2016  Canada       Transitional housing  Total, target population
# 7    2016  Canada       Transitional housing     General - all genders
# 8    2016  Canada       Transitional housing             General - men
# 9    2016  Canada       Transitional housing           General - women
# 10   2016  Canada       Transitional housing                     Youth
# 11   2016  Canada       Transitional housing                    Family
# ...

# %%
for i in range(6, 17):
    df_canada.drop(columns = "Unnamed: " + str(i), inplace = True)
    df_ontario.drop(columns = "Unnamed: " + str(i), inplace = True)
    df_sudbury.drop(columns = "Unnamed: " + str(i), inplace = True)
df_canada
# Out:
#      YEAR     GEO            Type of shelter         Target population  \
# 0    2016  Canada          Emergency shelter  Total, target population
# 1    2016  Canada          Emergency shelter     General - all genders
# 2    2016  Canada          Emergency shelter             General - men
# 3    2016  Canada          Emergency shelter           General - women
# 4    2016  Canada          Emergency shelter                     Youth
# 5    2016  Canada          Emergency shelter                    Family
# 6    2016  Canada       Transitional housing  Total, target population
# 7    2016  Canada       Transitional housing     General - all genders
# 8    2016  Canada       Transitional housing             General - men
# 9    2016  Canada       Transitional housing           General - women
# 10   2016  Canada       Transitional housing                     Youth
# 11   2016  Canada       Transitional housing                    Family
# ...

# %%
pd.set_option('display.max.rows', 300)

# %%
df_canada
# Out:
#      YEAR     GEO            Type of shelter         Target population  \
# 0    2016  Canada          Emergency shelter  Total, target population
# 1    2016  Canada          Emergency shelter     General - all genders
# 2    2016  Canada          Emergency shelter             General - men
# 3    2016  Canada          Emergency shelter           General - women
# 4    2016  Canada          Emergency shelter                     Youth
# 5    2016  Canada          Emergency shelter                    Family
# 6    2016  Canada       Transitional housing  Total, target population
# 7    2016  Canada       Transitional housing     General - all genders
# 8    2016  Canada       Transitional housing             General - men
# 9    2016  Canada       Transitional housing           General - women
# 10   2016  Canada       Transitional housing                     Youth
# 11   2016  Canada       Transitional housing                    Family
# ...

# %%
df_ontario
# Out:
#      YEAR     GEO            Type of shelter         Target population  \
# 0    2016  Canada          Emergency shelter  Total, target population
# 1    2016  Canada          Emergency shelter     General - all genders
# 2    2016  Canada          Emergency shelter             General - men
# 3    2016  Canada          Emergency shelter           General - women
# 4    2016  Canada          Emergency shelter                     Youth
# 5    2016  Canada          Emergency shelter                    Family
# 6    2016  Canada       Transitional housing  Total, target population
# 7    2016  Canada       Transitional housing     General - all genders
# 8    2016  Canada       Transitional housing             General - men
# 9    2016  Canada       Transitional housing           General - women
# 10   2016  Canada       Transitional housing                     Youth
# 11   2016  Canada       Transitional housing                    Family
# ...

# %%
df_ontario
# Out:
#      YEAR     GEO            Type of shelter         Target population  \
# 0    2016  Canada          Emergency shelter  Total, target population
# 1    2016  Canada          Emergency shelter     General - all genders
# 2    2016  Canada          Emergency shelter             General - men
# 3    2016  Canada          Emergency shelter           General - women
# 4    2016  Canada          Emergency shelter                     Youth
# 5    2016  Canada          Emergency shelter                    Family
# 6    2016  Canada       Transitional housing  Total, target population
# 7    2016  Canada       Transitional housing     General - all genders
# 8    2016  Canada       Transitional housing             General - men
# 9    2016  Canada       Transitional housing           General - women
# 10   2016  Canada       Transitional housing                     Youth
# 11   2016  Canada       Transitional housing                    Family
# ...

# %%
from git import repo
# Out:
# fatal: not a git repository (or any of the parent directories): .git
